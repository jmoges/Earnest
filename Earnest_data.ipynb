# %%
import pandas as pd
import boto3
import os 
from dotenv import load_dotenv
from functools import lru_cache

# %%
@lru_cache()
def cache_dotenv():
    return load_dotenv()

# %%
KEY                    = os.environ.get('KEY')
SECRET                 = os.environ.get('SECRET')

S3_Bucket              = os.environ.get("S3_Bucket")
S3_Prefix              = os.environ.get("S3_Prefix")
S3_Path                = os.environ.get("S3_Path")

# %%
# EARN_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

# (DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["KEY", "SECRET", "S3_Bucket", "S3_Prefix", "S3_Path"],
              "Value":
                  [KEY, SECRET, S3_Bucket, S3_Prefix, S3_Path]
             })
# Out:
#        Param                                     Value
# 0        KEY                      AKIA3E4BU4DC3XNHFAUH
# 1     SECRET  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
# 2  S3_Bucket               earnest-spend-279-us-east-1
# 3  S3_Prefix                               query/v1.0/
# 4    S3_Path                                      None

# %%
s3 = boto3.resource('s3',
                   region_name = 'us-east-1',
                   aws_access_key_id=KEY,
                    aws_secret_access_key=SECRET)

# %%
bucket=s3.Bucket(S3_Bucket) 

S3_Bucket
# Out:
# 'earnest-spend-279-us-east-1'

# %%
data = [filename.key for filename in bucket.objects.filter(Prefix=S3_Prefix)]
print(len(data))
data[:10]
# Out:
# 15315
# ['query/v1.0/2021/05/17/QuerySpend_DataDictionary.xlsx',
#  'query/v1.0/2021/05/17/consensus/consensus.gz',
#  'query/v1.0/2021/05/17/cs_panel_spend/part-00000-601c0c36-bc06-4abe-95da-9a9ee1cf43a7-c000.csv.gz',
#  'query/v1.0/2021/05/17/ddl_change_in_spend.sql',
#  'query/v1.0/2021/05/17/ddl_change_in_spend_channel.sql',
#  'query/v1.0/2021/05/17/ddl_cohort_retention.sql',
#  'query/v1.0/2021/05/17/ddl_consensus.sql',
#  'query/v1.0/2021/05/17/ddl_cross_shop.sql',
#  'query/v1.0/2021/05/17/ddl_cross_shop_channel.sql',
#  'query/v1.0/2021/05/17/ddl_cs_panel_spend.sql']

# %%
data = [filename.key for filename in bucket.objects.filter(Prefix="query/v1.0/2021/05/25")]
print(len(data))
data[:10]
# Out:
# 1301
# ['query/v1.0/2021/05/25/QuerySpend_DataDictionary.xlsx',
#  'query/v1.0/2021/05/25/consensus/consensus.gz',
#  'query/v1.0/2021/05/25/cs_panel_spend/part-00000-3f8258cc-2805-4a5c-baba-ec2ac7fd3fee-c000.csv.gz',
#  'query/v1.0/2021/05/25/ddl_change_in_spend.sql',
#  'query/v1.0/2021/05/25/ddl_change_in_spend_channel.sql',
#  'query/v1.0/2021/05/25/ddl_cohort_retention.sql',
#  'query/v1.0/2021/05/25/ddl_consensus.sql',
#  'query/v1.0/2021/05/25/ddl_cross_shop.sql',
#  'query/v1.0/2021/05/25/ddl_cross_shop_channel.sql',
#  'query/v1.0/2021/05/25/ddl_cs_panel_spend.sql']

# %%
list(map(lambda x: x.split("/")[-1],data)).sort()

# %%
sorted(list(map(lambda x: x.split("/")[-1],data)))
# Out:
# ['QuerySpend_DataDictionary.xlsx',
#  'consensus.gz',
#  'ddl_change_in_spend.sql',
#  'ddl_change_in_spend_channel.sql',
#  'ddl_cohort_retention.sql',
#  'ddl_consensus.sql',
#  'ddl_cross_shop.sql',
#  'ddl_cross_shop_channel.sql',
#  'ddl_cs_panel_spend.sql',
#  'ddl_customer_metrics.sql',
#  'ddl_machine_data_daily.sql',
#  'ddl_machine_data_daily_enhanced.sql',
#  'ddl_machine_data_quarter.sql',
#  'ddl_quintile_cohort.sql',
#  'ddl_subscription_cohort.sql',
#  'ddl_ticker_to_merchant_mapping.sql',
#  'ddl_ticket_frequency_daily.sql',
#  'machine_data_daily.gz',
#  'machine_data_quarter.gz',
#  'part-00000-3f8258cc-2805-4a5c-baba-ec2ac7fd3fee-c000.csv.gz',
#  'part-00000-507aeef4-d110-44da-a23e-90d0d1fa7ab3-c000.csv.gz',
#  'part-00001-507aeef4-d110-44da-a23e-90d0d1fa7ab3-c000.csv.gz',
#  'part-00002-507aeef4-d110-44da-a23e-90d0d1fa7ab3-c000.csv.gz',
#  'part-00003-507aeef4-d110-44da-a23e-90d0d1fa7ab3-c000.csv.gz',
# ...
